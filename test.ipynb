# %%
from amber_to_lammps import amber2lammps, validate_files
import subprocess

data_file = 'data.lammps'
param_file = 'parm.lammps'
topology = 'epon.prmtop'
crd = 'epon.crd'

# Optional validation
validate_files(topology, crd)

# Convert
amber2lammps(
    data_file=data_file,
    param_file=param_file,
    topology=topology,
    crd=crd,
    charge=0,
    buffer=3.8,
    verbose=True,
    keep_temp=False
)

# # Run LAMMPS
# subprocess.run("lmp < example_lammps_input.lmp", shell=True)
# print("Completed conversion")
# Out:
# Converting AMBER files to LAMMPS format...
# Output files: data.lammps, parm.lammps
# Loading topology from epon.prmtop...
# Found 53 atoms
# Found 54 bonds
# Found 94 angles
# Found 160 dihedrals
# Extracting LJ coefficients and atom information from topology...
# Parsing atom types and masses from topology...
# Found 8 atom types
# Parsing coordinates from epon.crd...
# Extracting charges from topology...
# Parsed 53 coordinates from CRD file
# Box dimensions: X[-1.655, 24.356], Y[-3.199, 10.296], Z[-10.275, 3.310]
# Current net charge: -0.002996
# Target net charge: 0
# Applied uniform shift of 0.000057 per atom to achieve target charge
# New net charge: 0.000000
# Writing atoms section...
# Writing bonds section...
# Writing angles section...
# Writing dihedrals section...
# Cleaning up temporary files...
# Conversion complete!
# Generated files:
#   - data.lammps (LAMMPS data file)
#   - parm.lammps (LAMMPS parameters)
# Summary:
#   - 53 atoms
#   - 54 bonds
#   - 94 angles
#   - 160 dihedrals
